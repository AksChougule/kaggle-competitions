# %% [markdown]
# Notes
# - ResNet50 model
# - half-sized training
# - LR = 1e-4
# - epoch 10

# %%
import os
import gc
#import jovian

import numpy as np 
import pandas as pd

from pathlib import Path

from fastai import *
from fastai.vision import *
from fastai.callbacks.hooks import *

# %% [markdown]
# ## Data Preparation

# %%
data_folder = Path('/home/ubuntu/datasets/severstal-steel-defect-detection/')
train_images = data_folder / 'train_images'
test_images = data_folder / 'test_images'

# %%
# use fastai function to get the training images
fnames = get_image_files(train_images)
fnames[:3]
# Out:
# [PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/train_images/10e429bfc.jpg'),
#  PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/train_images/c4d5657bc.jpg'),
#  PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/train_images/2a351164a.jpg')]

# %%
# take a look at the one of the training images
# - choosing an image that has defects on the matching mask
img_f = train_images/'000f6bf48.jpg'
img = open_image(img_f)
img.show(figsize=(15,3))

# %% [markdown]
# ## Use pre-made segmentation masks
#
# Using pre-created segmentation masks that were made using this notebook:
#
# https://www.kaggle.com/nikhilikhar/steel-create-labels?scriptVersionId=18640338

# %%
path_lbl = Path('/home/ubuntu/datasets/severstal-steel-defect-detection/labels-img/')

# %% [markdown]
# https://forums.fast.ai/t/unet-segmentation-mask-converter-to-help-against-common-errors-problems/42949

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/labels-img/ccbeeb18a.png'),
#  PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/labels-img/4598f8be0.png'),
#  PosixPath('/home/ubuntu/datasets/severstal-steel-defect-detection/labels-img/b162a9cb2.png')]

# %%
def get_y_fn(x):
    x = Path(x)
    return path_lbl/f'{x.stem}.png'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(15,3), alpha=1)

# %%
train_df = pd.read_csv(data_folder / 'train.csv')
train_df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
# get the training image with the most defects
train_df.ImageId.mode()
# Out:
# 0    db4867ee8.jpg
# 1    ef24da2ba.jpg
# dtype: object

# %%
# get all the rows belonging to the image with the most defects
most_defects = train_df.loc[train_df['ImageId'] == "db4867ee8.jpg"]
most_defects
# Out:
#             ImageId  ClassId  \
# 6101  db4867ee8.jpg        1
# 6102  db4867ee8.jpg        2
# 6103  db4867ee8.jpg        3
#
#                                           EncodedPixels
# 6101  349941 2 350194 6 350447 11 350700 15 350953 1...
# 6102  354411 17 354634 50 354857 82 355096 99 355351...
# 6103                              233729 3008 236801 64

# %%
train_df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
img_f = train_images/"db4867ee8.jpg"
img = open_image(img_f)
img.show(figsize=(20,10))

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(20,10), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([ 256, 1600]),
#  tensor([[[4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           ...,
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4]]]))

# %%
img.show(y=mask, figsize=(20, 10), title=f"{img_f.name} with mask, label 1")

# %%
# premade mask
mask = open_mask(get_y_fn("0025bde0c.jpg"))
mask.show(figsize=(20,10), alpha=1)

# %%
mask.shape
# Out:
# torch.Size([1, 256, 1600])

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([ 256, 1600]),
#  tensor([[[4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           ...,
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4],
#           [4, 4, 4,  ..., 4, 4, 4]]]))

# %%
from fastai.utils.mem import *
free = gpu_mem_get_free_no_cache()

# the max size of bs depends on the available GPU RAM
# if free > 8200: batch_size=16
# else:           batch_size=4
# print(f"using bs={batch_size}, have {free}MB of GPU RAM free")

batch_size=1

# %%
codes = ['0','1','2','3','4']

# half the size of the images
size = src_size//2
size
# Out:
# array([128, 800])

# %%
# need to define a function that does nothing to get around a problem in Fastai
# when adding the test images to the DataBunch
def no_tfms(self, x, **kwargs): return x
EmptyLabel.apply_tfms = no_tfms

# %%
src = (SegmentationItemList.from_df(train_df, train_images)
       .split_by_rand_pct()
       .label_from_func(get_y_fn, classes=codes)
       .add_test_folder(test_images, label=None))
src
# Out:
# LabelLists;
#
# Train: LabelList (5676 items)
# x: SegmentationItemList
# Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600)
# y: SegmentationLabelList
# ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600)
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images;
#
# Valid: LabelList (1419 items)
# x: SegmentationItemList
# Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600)
# y: SegmentationLabelList
# ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600),ImageSegment (1, 256, 1600)
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images;
#
# Test: LabelList (5506 items)
# x: SegmentationItemList
# Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600),Image (3, 256, 1600)
# y: EmptyLabelList
# ,,,,
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images

# %%
data = (src.transform(get_transforms(), tfm_y=True, size=size)        
        .databunch(bs=batch_size)
        .normalize(imagenet_stats))
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (5676 items)
# x: SegmentationItemList
# Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800)
# y: SegmentationLabelList
# ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800)
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images;
#
# Valid: LabelList (1419 items)
# x: SegmentationItemList
# Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800)
# y: SegmentationLabelList
# ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800),ImageSegment (1, 128, 800)
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images;
#
# Test: LabelList (5506 items)
# x: SegmentationItemList
# Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800),Image (3, 128, 800)
# y: EmptyLabelList
# [RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)],[RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)],[RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)],[RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)],[RandTransform(tfm=TfmCrop (crop_pad), kwargs={}, p=1.0, resolved={'padding_mode': 'reflection', 'row_pct': 0.5, 'col_pct': 0.5}, do_run=True, is_random=True, use_on_y=True)]
# Path: /home/ubuntu/datasets/severstal-steel-defect-detection/train_images

# %%
data.show_batch(2, figsize=(16,3))

# %%
data.show_batch(2, figsize=(16,3),ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %% [markdown]
# from: https://www.kaggle.com/nikhilikhar/fastai-steel-unet/notebook

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = 4
wd=1e-2

def acc_steel(input, target):
#     import pdb; pdb.set_trace()
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

def dice(pred, targs):
    pred = (pred>0).float()
    return 2. * (pred*targs).sum() / (pred+targs).sum()

def iou(input:Tensor, targs:Tensor) -> Rank0Tensor:
    "IoU coefficient metric for binary target."
    n = targs.shape[0]
    input = input.argmax(dim=1).view(n,-1)
    targs = targs.view(n,-1)
    intersect = (input*targs).sum().float()
    union = (input+targs).sum().float()
    return intersect / (union-intersect+1.0)

metrics = [acc_steel, iou]

# %%
learn = unet_learner(data, models.resnet50, metrics=metrics, wd=wd, bottle=True, 
                     model_dir="~/kaggle/working/models");

# %%
gc.collect()
# Out:
# 11967

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_steel</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='61' class='' max='5676' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.07% [61/5676 00:26<40:48 1.5234]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-4
epoch = 10
learn.fit_one_cycle(epoch, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_steel</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.170436</td>
#       <td>0.128080</td>
#       <td>0.466565</td>
#       <td>-2.046924</td>
#       <td>37:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.154581</td>
#       <td>0.118224</td>
#       <td>0.330852</td>
#       <td>-2.040232</td>
#       <td>37:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.146224</td>
#       <td>0.129201</td>
#       <td>0.615869</td>
#       <td>-2.055203</td>
#       <td>37:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.140301</td>
#       <td>0.118353</td>
#       <td>0.455360</td>
#       <td>-2.040790</td>
#       <td>37:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.115463</td>
#       <td>0.135856</td>
#       <td>0.380857</td>
#       <td>-2.037812</td>
#       <td>37:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.091354</td>
#       <td>0.121497</td>
#       <td>0.508421</td>
#       <td>-2.044198</td>
#       <td>37:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.139634</td>
#       <td>0.134051</td>
#       <td>0.541787</td>
#       <td>-2.045054</td>
#       <td>37:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.115440</td>
#       <td>0.167677</td>
#       <td>0.489293</td>
#       <td>-2.043933</td>
#       <td>37:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.096769</td>
#       <td>0.109656</td>
#       <td>0.558305</td>
#       <td>-2.045861</td>
#       <td>37:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.134819</td>
#       <td>0.111712</td>
#       <td>0.559061</td>
#       <td>-2.045740</td>
#       <td>37:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')
learn.export("~/kaggle/working/steel-1.pkl")

# %%
learn.show_results(ds_type=DatasetType.Train, rows=4, figsize=(20,10))

# %%
lr=1e-3
epoch = 10
learn.fit_one_cycle(epoch, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_steel</th>
#       <th>iou</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.090479</td>
#       <td>0.122285</td>
#       <td>0.565145</td>
#       <td>-2.047127</td>
#       <td>36:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.085324</td>
#       <td>0.133698</td>
#       <td>0.446560</td>
#       <td>-2.040616</td>
#       <td>36:47</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.128392</td>
#       <td>0.311518</td>
#       <td>0.480232</td>
#       <td>-2.082222</td>
#       <td>36:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.162935</td>
#       <td>0.269029</td>
#       <td>0.639928</td>
#       <td>-2.063681</td>
#       <td>36:41</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.114322</td>
#       <td>0.128192</td>
#       <td>0.409075</td>
#       <td>-2.038043</td>
#       <td>36:37</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.106301</td>
#       <td>0.117032</td>
#       <td>0.510499</td>
#       <td>-2.043046</td>
#       <td>36:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.091548</td>
#       <td>0.128955</td>
#       <td>0.475528</td>
#       <td>-2.041032</td>
#       <td>36:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.098173</td>
#       <td>0.110187</td>
#       <td>0.417513</td>
#       <td>-2.039132</td>
#       <td>36:28</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.138216</td>
#       <td>0.196373</td>
#       <td>0.669976</td>
#       <td>-2.065484</td>
#       <td>36:27</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.091313</td>
#       <td>0.148190</td>
#       <td>0.518698</td>
#       <td>-2.041594</td>
#       <td>36:27</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Test Set Predictions**

# %%
from itertools import groupby

def encode(input_string):
    return [(len(list(g)), k) for k,g in groupby(input_string)]

def run_length(label_vec):
    encode_list = encode(label_vec)
    index = 1
    class_dict = {}
    for i in encode_list:
        if i[1] != len(codes)-1:
            if i[1] not in class_dict.keys():
                class_dict[i[1]] = []
            class_dict[i[1]] = class_dict[i[1]] + [index, i[0]]
        index += i[0]
    return class_dict

# %%
test_df = pd.read_csv(data_folder / 'sample_submission.csv')
test_df.head()
# Out:
#          ImageId EncodedPixels  ClassId
# 0  0000f269f.jpg      1 409600        0
# 1  000ccc2ac.jpg      1 409600        0
# 2  002451917.jpg      1 409600        0
# 3  003c5da97.jpg      1 409600        0
# 4  0042e163f.jpg      1 409600        0

# %%
from tqdm import tqdm, notebook

def get_predictions():
    results = []
    for index, row in tqdm(test_df.iterrows(), total=test_df.shape[0]):

        img_name = row['ImageId']   
        img = open_image(test_images/img_name)
        pred = learn.predict(img)[1].data.numpy().flatten()
        class_dict = run_length(pred)

        for i in range(4):
            rle = ''
            if i in class_dict: rle = " ".join(map(str, class_dict[i]))
            results.append([img_name + "_" + str(i+1), rle])     
    return results
    
sub_list = get_predictions()
# Out:
# 100%|██████████| 5506/5506 [05:21<00:00, 17.13it/s]

# %%
# create the submission dataframe 
# - creating this in old format as having problems submitting in new format
submission_df = pd.DataFrame(sub_list, columns=['ImageId_ClassId', 'EncodedPixels'])
submission_df.head()
# Out:
#    ImageId_ClassId                                      EncodedPixels
# 0  0000f269f.jpg_1                            41513 1 42313 1 43113 1
# 1  0000f269f.jpg_2
# 2  0000f269f.jpg_3  288 10 1087 11 1888 10 2688 10 3488 10 4288 10...
# 3  0000f269f.jpg_4
# 4  000ccc2ac.jpg_1  17535 1 18335 1 18337 1 19135 5 19935 4 20733 ...

# %%
submission_df.to_csv("submission.csv", index=False)
